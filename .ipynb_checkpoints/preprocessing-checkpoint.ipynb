# %% [markdown]
# ## Preprocessing Open Street Map Data

# %% [markdown]
# 1. Test osmgraph

# %%
import osmgraph

# %%
g = osmgraph.parse_file("hawaii-latest.osm.bz2")
# Out:
# Process Process-1:
# Traceback (most recent call last):
#   File "/Users/xutianyu/anaconda2/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/Users/xutianyu/anaconda2/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/xutianyu/anaconda2/lib/python2.7/site-packages/imposm/parser/simple.py", line 113, in parse_it
#     parser.parse(input)
#   File "/Users/xutianyu/anaconda2/lib/python2.7/site-packages/imposm/parser/xml/multiproc.py", line 110, in parse
#     chunker.read(self.mmap_queue, coords_callback=self.coords_callback)
#   File "/Users/xutianyu/anaconda2/lib/python2.7/site-packages/imposm/parser/xml/multiproc.py", line 211, in read
#     xml_nodes.write(self._last_line)
# TypeError: write() argument 1 must be string or read-only buffer, not None
# ---------------------------------------------------------------------------
# ...

# %%
len(g.node)

# %%
#coding:utf-8
import networkx as nx
import matplotlib.pyplot as plt
#此段代码解决 1.matplotlib中文显示问题 2 '-'显示为方块问题
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False
def show(G,pos,title=None,photo_name='picture'):
    e_1 =[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] ==1] # 普通边
    e_2 =[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] ==0] # 利用的边
    # Draw nodes
    nx.draw_networkx_nodes(G,pos,node_size=300, node_color='orange')
    # Draw Edges
    nx.draw_networkx_edges(G,pos,edgelist=e_1,width=1, alpha = 1,edge_color='g',style='dashed')
    nx.draw_networkx_edges(G,pos,edgelist=e_2, width=3,alpha=0.6,edge_color='b')
    edge_labels =dict([((u, v), d['weight']) for u, v, d in G.edges(data=True)])
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    nx.draw_networkx_labels(G,pos,font_size=10)
    plt.title(title)
    plt.axis('off')
    plt.savefig(photo_name)
    plt.show()
    
#%% read in data - use a pandas dataframe just for convenience
import pandas as pd
data = pd.read_table("~/Desktop/Project/data/melbourne_graph.txt",
                     sep = " ",
                     header = None, 
                     names = ['vx', 'vy', 'weight'])

# %% use network x to prepare dictionary structure which can be fed in to the 
# dijkstra function
import networkx as nx
graph = nx.from_pandas_edgelist(data, 'vx', 'vy', 'weight')
# graph_nodes = graph.nodes()
graph_dict = nx.to_dict_of_dicts(graph)
G = nx.Graph(graph_dict)
pos = nx.shell_layout(G) 
#show(G,pos)
print data

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
#Let g be a graph that I created
edges = pd.read_table("data/smallGraph.txt",
                      sep=" ",
                      header=None,
                      names=['vx', 'vy', 'weight'])

graph = nx.from_pandas_edgelist(edges, 'vx', 'vy', 'weight')
graph_nodes = graph.nodes()

nx.draw(graph, node_size=2)
plt.draw()
plt.savefig('picture/small_plot.png')
plt.show()
plt.clf()

# %%
import metis
(edgecuts, parts) = metis.part_graph(graph, 4)
colors = ['red','blue','green', 'yellow']
node_colors = []
for i in range(len(parts)):
    node_colors.append(colors[parts[i]])

# for i, p in enumerate(parts):
#     graph.node[i]['color'] = colors[p]
# nx.draw(graph, 'partition.dot') # Requires pydot or pygraphviz
nx.draw(graph, node_size=4, node_color=node_colors)
plt.draw()
plt.savefig('picture/melbourne_partition_plot.png')
plt.show()
plt.clf()

# %%
red_nodes = [i for i in range(len(parts)) if parts[i] == 0]
nx.draw(graph, nodelist=red_nodes ,node_size=4)
plt.draw()
plt.savefig('picture/melbourne_partition_part1_plot.png')
plt.show()
plt.clf()

# %%
blue_nodes = [i for i in range(len(parts)) if parts[i] == 1]
nx.draw(graph, nodelist=blue_nodes ,node_color='blue', node_size=4)
plt.draw()
plt.savefig('picture/melbourne_partition_part2_plot.png')
plt.show()
plt.clf()

# %%
part_nodes =list(graph.nodes())[:100]

degree = edges.vx.value_counts()
landmarks = degree[0:20].index

pos = nx.spring_layout(graph)
sub = graph.subgraph(landmarks)
nx.draw_networkx(sub, pos = pos)
plt.savefig('picture/melbourne_part_plot.png')
plt.show()
plt.clf()

# %%
print(len(sub))
# Out:
# 3619

# %%
print nx.dijkstra_path_length(graph, source=19, target=25)
# Out:
# 474.31149476324

# %%
length = nx.single_source_dijkstra_path_length(graph, 19)
print length[1166]
# Out:
# 13.0900357212

# %%
edges = pd.read_table("data/bigMelbourneGraph.txt",
                      sep=" ",
                      header=None,
                      names=['vx', 'vy', 'weight'])

graph2 = nx.from_pandas_edgelist(edges, 'vx', 'vy', 'weight')

# %%
(edgecuts2, parts2) = metis.part_graph(graph2, 100)

# %%
print edgecuts2
# Out:
# 1397

# %%
import numpy as np
graph_dict = nx.to_dict_of_dicts(graph)
G = nx.Graph(graph_dict)
d = 2196
distanceMatrix = np.zeros((d, d), dtype=np.float16)
for i in range(d):
    if i in graph_dict.keys():
        length = nx.single_source_dijkstra_path_length(G, i)
        temp = []
        for j in range(d):
            if j in length.keys():
                distanceMatrix[i, j] = length[j]
    print(str(i) + "th completed")
# Out:
# 0th completed
# 1th completed
# 2th completed
# 3th completed
# 4th completed
# 5th completed
# 6th completed
# 7th completed
# 8th completed
# 9th completed
# 10th completed
# 11th completed
# 12th completed
# 13th completed
# 14th completed
# 15th completed
# 16th completed
# 17th completed
# 18th completed
# 19th completed
# 20th completed
# 21th completed
# 22th completed
# 23th completed
# 24th completed
# 25th completed
# 26th completed
# 27th completed
# 28th completed
# 29th completed
# 30th completed
# 31th completed
# 32th completed
# 33th completed
# 34th completed
# 35th completed
# 36th completed
# 37th completed
# 38th completed
# 39th completed
# 40th completed
# 41th completed
# 42th completed
# 43th completed
# 44th completed
# 45th completed
# 46th completed
# 47th completed
# 48th completed
# 49th completed
# 50th completed
# 51th completed
# 52th completed
# 53th completed
# 54th completed
# 55th completed
# 56th completed
# 57th completed
# 58th completed
# ...

# %%
def shuffle(size):
    # random shuffle input data
    index = np.zeros(shape=(size * size, 2), dtype=np.int8)
    for i in range(size):
        for j in range(size):
            index[i * size + j, 0] = i
            index[i * size + j, 1] = j
    np.random.shuffle(index)

    return index

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

index = shuffle(d)[:1000]
size = 50
x_train = np.zeros(shape=(size, 2 * d))
y_train = np.zeros(shape=(size))
for i in range(size):
    x = index[i][0]
    y = index[i][1]
    vx = np.squeeze(np.asarray(
        distanceMatrix[x, :]))
    vy = np.squeeze(np.asarray(
        distanceMatrix[y, :]))
    x_train[i] = np.concatenate([vx, vy])
    y_train[i] = distanceMatrix[x, y]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(x_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(x_train)

# # The coefficients
# print('Coefficients: \n', regr.coef_)
# # The mean squared error
# print("Mean squared error: %.2f"
#       % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# # Explained variance score: 1 is perfect prediction
# print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(x_train, y_train,  color='black')
plt.plot(x_train, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.draw()
plt.savefig('picture/melbourne_part_plot.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4f696b2e091a> in <module>()
#      36
#      37 # Plot outputs
# ---> 38 plt.scatter(x_train, y_train,  color='black')
#      39 plt.plot(x_train, y_pred, color='blue', linewidth=3)
#      40
#
# /Users/xutianyu/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# /Users/xutianyu/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
#Let g be a graph that I created
edges = pd.read_table("data/smallGraph.txt",
                      sep=" ",
                      header=None,
                      names=['vx', 'vy', 'weight'])

graph = nx.from_pandas_edgelist(edges, 'vx', 'vy', 'weight')
graph_nodes = graph.nodes()

graph_dict = nx.to_dict_of_dicts(graph)
G = nx.Graph(graph_dict)
import timeit
start = timeit.default_timer()
length = nx.single_source_dijkstra_path_length(G, 0)
print length
end = timeit.default_timer()
print(end - start)
# Out:
# 0.0194070339203
